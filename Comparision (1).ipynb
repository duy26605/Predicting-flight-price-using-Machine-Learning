# %%
from PIL import Image
from IPython.display import display

# %%
# Learning cruve for Decision Tree 
img = Image.open('Screen Shot 2024-03-25 at 11.27.37 PM.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1484x1044 at 0x7F85CD1D6700>

# %%
# Learning cruve for SGDRegression
img_sgd = Image.open('Screen Shot 2024-03-25 at 11.27.56 PM.png')
display(img_sgd)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1326x1042 at 0x7F854152DCD0>

# %%
# Comparison:
# - Model Performance: The gap between the cross-validation and training scores is 
# notably narrower for the SGDRegressor compared to the Decision Tree Regressor. 
# This indicates that the SGDRegressor is more generalizable to unseen data. Additionally, the error
# rate of the SGDRegressor is significantly lower (17% vs. 34%), suggesting it has a stronger 
# predictive capability for this dataset.

# - Error Metrics: In terms of the Root Mean Square Error (RMSE), the SGDRegressor outperforms 
# the Decision Tree Regressor. This metric further underscores the SGDRegressor's superior 
# accuracy in predicting continuous values.
# - Learning Curve Analysis: The learning curve of the SGDRegressor demonstrates convergence at 
# a sample size of approximately 4000. This behavior suggests that adding more data beyond 
# this point does not significantly improve the model's performance, indicating the model has 
# reached its learning capacity with the current feature set.
